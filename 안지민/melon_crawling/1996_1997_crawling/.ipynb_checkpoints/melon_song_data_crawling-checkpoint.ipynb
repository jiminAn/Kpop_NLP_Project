# %% [markdown]
# # 환경설치

# %%
# !pip install html5lib beautifulsoup4
# !pip install selenium

from selenium import webdriver
from bs4 import BeautifulSoup
from time import sleep
import requests
import json
import re
import pandas as pd

# %%
from urllib import request
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException

# %%
from selenium.webdriver.common.keys import Keys

# %%
import numpy as np

# %% [markdown]
# # 아이돌별 멜론 아이디가 지정된 파일 읽기

# %%
# 인코딩이 euc-kr입니다. 저걸 지정하지 않으면 csv가 안 열려요!
# idol_id가 저장된 csv 파일을 불러오셔야 합니다. 멜론 url에 가수를 찾기 위한 id입니다. 

idol_list = pd.read_csv('1996_1997_debut.csv', encoding='euc-kr')
idol_list.head()
# Out:
#      artist artist_eng member_num leader_name gender          agency  idol_id
# 0      언타이틀    Untitle          2         유건형      남  예당 음향 (예당 컴퍼니)   100042
# 1  Hamohamo  HAMO HAMO          2         이성진      남          뮤직 팩토리   100178
# 2       아이돌       IDOL          2         최혁준      남         DSP 미디어   101640
# 3        구피      Goofy          3         이승광      남             NaN   100023
# 4       태사자    Taesaja          4         김형준      남             매스컴   100096

# %%
idol_list.shape
# Out:
# (10, 7)

# %%
idol_list = idol_list[np.isfinite(idol_list['idol_id'])].reset_index(drop=True)

# %%
idol_list.shape
# Out:
# (10, 7)

# %%
# id가 flaot으로 저장되어 있습니다. int로 바꿔주고 저장하겠습니다. 
idol_list['idol_id'] = idol_list['idol_id'].astype(int)
idol_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist       10 non-null     object
#  1   artist_eng   10 non-null     object
#  2   member_num   10 non-null     object
#  3   leader_name  9 non-null      object
#  4   gender       10 non-null     object
#  5   agency       8 non-null      object
#  6   idol_id      10 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 688.0+ bytes

# %%
# 수집을 위한 빈 리스트 생성

title = []
release_date = []
song_genre = []
lyrics = []
creator = []
artist = []
artist_m = []
debut_y = []
debut_t = []
agency = []

# %%
# 곡마다 가수 이름을 붙여주어야 하기에 가수 이름 리스트로 받아오기
names = idol_list.artist
names[0]
# Out:
# '언타이틀'

# %%
# 크롤러가 링크를 찾을 때 매번 바꿔주는 값. for문에 사용됩니다. 
ids = idol_list.idol_id
ids[0]
# Out:
# 100042

# %%
# tests = ['780066']

# %% [markdown]
# # 크롤러
# ### 아이돌별 96~99년도 발매한 곡만 수집
# : 수집 가능 목록 (발매날짜/제목/가사/작사/작곡)

# %%
path = "/Users/mac/opt/anaconda3/bin/chromedriver"
driver = webdriver.Chrome(path)
driver.get("https://www.melon.com")

# %%
# 곡 정보를 찾아들어가기 위한 url을 분해해서 변수 지정해놓은 모습입니다. 
# l3 뒤에 붙는 숫자가 멜론 서버에 저장된 해당 가수의 해당 곡 번호입니다. 

l1 = 'https://www.melon.com/artist/song.htm?artistId='
# idol_id
l2 = '#params%5BlistType%5D=A&params%5BorderBy%5D=ISSUE_DATE&params%5BartistId%5D='
# idol_id
l3 = '&po=pageObj&startIndex='
# l1 + 'idol_id' + l2 + 'idol_id' + l3 + number

# 가수 이름을 넣기 위한 변수
i = 0
tmp = []
str_tmp = ""
arr = []

for id in ids:
    
    n = 1
    list_n = 1
    while True:
    #for k in range(1):
                 
        
        print('n: ',n)
        driver.get(l1+str(id)+l2+str(id)+l3+str(n))    
        sleep(2)
        
                
        # 곡 정보로 들어가기
        try:
            driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul/li[3]/a').click()
            str_tmp = '//*[@id="frm"]/div/table/tbody/tr[' + str(list_n) + ']/td[3]/div/div/a[1]'
            driver.find_element_by_xpath(str_tmp).click()
            print('list: ',list_n)
            # 발매날짜 크롤링
            try:
                str_tmp = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[2]').text
                arr = str_tmp.split('.')
                print("check :",str_tmp)
                if( int(arr[0]) < 2000 and int(arr[0]) > 1995): # 96,97,98,99 발매 노래만
                    print("input: ", str_tmp)
                    release_date.append(str_tmp)
                    list_n += 1
                elif (int(arr[0]) < 1996): # 96년 이전 발매일 경우 break
                    break
                else:
                    list_n += 1
                    continue
                
            
            except NoSuchElementException as e:
                release_date.append('')
            
            # 제목 크롤링(제목은 없지 않기 때문에 예외 없음)
            title.append(driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[1]').text)
            print('title:', title)

            try:
                song_genre.append(driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]').text)
            except NoSuchElementException as e:
                song_genre.append('')

            # 가사 크롤링
            try:
                lyrics.append(driver.find_element_by_xpath('//*[@id="d_video_summary"]').text)
            except NoSuchElementException as e:
                lyrics.append('')

            # 작사 작곡 내역이 없는 경우
            try:
                creator.append(driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul').text)
            except NoSuchElementException as e:
                creator.append('')

            n += 1
            
            # 가수 이름 붙이기
            artist.append(names[i])
            
            # 디버깅    
            print(len(title), title[len(title)-1])

        except NoSuchElementException as e:
            i += 1
            break
# Out:
# n:  1
# list:  1
# check : 2007.12.24
# n:  1
# list:  2
# check : 2007.12.13
# n:  1
# list:  3
# check : 2003.11.01
# n:  1
# list:  4
# check : 2000.11.01
# n:  1
# list:  5
# check : 1999.08.01
# input:  1999.08.01
# title: ['떠나가지 마세요']
# 1 떠나가지 마세요
# n:  2
# list:  6
# check : 1999.03.05
# input:  1999.03.05
# title: ['떠나가지 마세요', '학교 (Main Title)']
# 2 학교 (Main Title)
# n:  3
# list:  7
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요']
# 3 떠나가지 마세요
# n:  4
# list:  8
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기']
# 4 나의 슬픈 사랑이야기
# n:  5
# list:  9
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가']
# 5 사랑연가
# n:  6
# list:  10
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!']
# 6 댄스! 댄스! 댄스!
# n:  7
# list:  11
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑']
# 7 하얀 사랑
# n:  8
# list:  12
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤']
# 8 낮과 밤
# n:  9
# list:  13
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연']
# 9 인연
# n:  10
# list:  14
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선']
# 10 검은 위선
# n:  11
# list:  15
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2']
# 11 Love Song #2
# n:  12
# list:  16
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run']
# 12 Run
# n:  13
# list:  17
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy']
# 13 Play Boy
# n:  14
# list:  18
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye']
# 14 Goodbye
# n:  15
# list:  19
# check : 1999.02.01
# input:  1999.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다']
# 15 우리가 시작할때...거기엔 랩이 있었다
# n:  16
# list:  20
# check : 1998.02.01
# input:  1998.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro']
# 16 Intro
# n:  17
# list:  21
# check : 1998.02.01
# input:  1998.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃']
# 17 꽃
# n:  18
# list:  22
# check : 1998.02.01
# input:  1998.02.01
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리']
# 18 승리
# n:  19
# list:  23
# n:  1
# list:  1
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang']
# 19 Pang Pang
# n:  2
# list:  2
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)']
# 20 빠삐용 (그의 두통은 자유였다)
# n:  3
# list:  3
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!']
# 21 마라! 봐라!
# n:  4
# list:  4
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써']
# 22 아니벌써
# n:  5
# list:  5
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line']
# 23 Silver Line
# n:  6
# list:  6
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love']
# 24 True Love
# n:  7
# list:  7
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)']
# 25 반쪽만의 사랑 (My Teacher)
# n:  8
# list:  8
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드']
# 26 히든 카드
# n:  9
# list:  9
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디']
# 27 세상에 던지는 한마디
# n:  10
# list:  10
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)']
# 28 Pang Pang (나보다 나은 너)
# n:  11
# list:  11
# n:  1
# list:  1
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro']
# 29 Intro
# n:  2
# list:  2
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest']
# 30 Be My Guest
# n:  3
# list:  3
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험']
# 31 환상체험
# n:  4
# list:  4
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증']
# 32 건망증
# n:  5
# list:  5
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가']
# 33 이럴수가
# n:  6
# list:  6
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story']
# 34 Love Story
# n:  7
# list:  7
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)']
# 35 통화중 (감기)
# n:  8
# list:  8
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각']
# 36 삼인사각
# n:  9
# list:  9
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...']
# 37 어쨌건...
# n:  10
# list:  10
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)']
# 38 도사 (Jungle Trance)
# n:  11
# list:  11
# check : 1996.11
# input:  1996.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마']
# 39 귀여운 악마
# n:  12
# list:  12
# check : 1996.02
# input:  1996.02
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow']
# 40 Bow Wow
# n:  13
# list:  13
# check : 1996.02
# input:  1996.02
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy']
# 41 Home Boy
# n:  14
# list:  14
# check : 1996.02
# input:  1996.02
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy']
# 42 Street Boy
# n:  15
# list:  15
# check : 1996.02
# input:  1996.02
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑']
# 43 둘만의 사랑
# n:  16
# list:  16
# check : 1996.02
# input:  1996.02
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀']
# 44 꿈속의 그녀
# n:  17
# list:  17
# check : 1996.02
# input:  1996.02
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기']
# 45 노래 이야기
# n:  18
# list:  18
# check : 1996.02
# input:  1996.02
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기', 'Na Na Na']
# 46 Na Na Na
# n:  19
# list:  19
# check : 1996.02
# input:  1996.02
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기', 'Na Na Na', '상상']
# 47 상상
# n:  20
# list:  20
# check : 1971
# n:  1
# list:  1
# check : 2016.04.19
# n:  1
# list:  2
# n:  1
# list:  1
# check : 2020.08.01
# n:  1
# list:  2
# check : 2001.11.01
# n:  1
# list:  3
# check : 2001.11.01
# n:  1
# list:  4
# check : 2001.11.01
# n:  1
# list:  5
# check : 2001.11.01
# n:  1
# list:  6
# check : 2001.11.01
# n:  1
# list:  7
# check : 2001.11.01
# n:  1
# list:  8
# check : 2001.11.01
# n:  1
# list:  9
# check : 2001.11.01
# n:  1
# list:  10
# check : 2001.11.01
# n:  1
# list:  11
# check : 2001.11.01
# n:  1
# list:  12
# check : 2001.11.01
# n:  1
# list:  13
# check : 2001.11.01
# n:  1
# list:  14
# check : 2001.11.01
# n:  1
# list:  15
# check : 2001.11.01
# n:  1
# list:  16
# check : 2001.11.01
# n:  1
# list:  17
# check : 2001.11.01
# n:  1
# list:  18
# check : 2001.11.01
# n:  1
# list:  19
# check : 2001.11.01
# n:  1
# list:  20
# check : 2001.11.01
# n:  1
# list:  21
# check : 2001.11.01
# n:  1
# list:  22
# check : 2001.11.01
# n:  1
# list:  23
# check : 2001.11.01
# n:  1
# list:  24
# check : 2001.11.01
# n:  1
# list:  25
# check : 2001.11.01
# n:  1
# list:  26
# check : 2001.11.01
# n:  1
# list:  27
# check : 2001.11.01
# n:  1
# list:  28
# check : 2001.11.01
# n:  1
# list:  29
# check : 2001.11.01
# n:  1
# list:  30
# check : 2001.11.01
# n:  1
# list:  31
# check : 2001.11.01
# n:  1
# list:  32
# check : 2001.11.01
# n:  1
# list:  33
# check : 2001.11.01
# n:  1
# list:  34
# check : 2000.06.20
# n:  1
# list:  35
# check : 2000.06.20
# n:  1
# list:  36
# check : 2000.06.20
# n:  1
# list:  37
# check : 2000.06.20
# n:  1
# list:  38
# check : 2000.06.20
# n:  1
# list:  39
# check : 2000.06.20
# n:  1
# list:  40
# check : 2000.06.20
# n:  1
# list:  41
# check : 2000.06.20
# n:  1
# list:  42
# check : 2000.06.20
# n:  1
# list:  43
# check : 2000.06.20
# n:  1
# list:  44
# check : 2000.06.20
# n:  1
# list:  45
# check : 2000.06.20
# n:  1
# list:  46
# check : 2000.06.20
# n:  1
# list:  47
# check : 1999.07
# input:  1999.07
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기', 'Na Na Na', '상상', 'Memory']
# 48 Memory
# n:  2
# list:  48
# check : 1999.07
# input:  1999.07
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기', 'Na Na Na', '상상', 'Memory', 'Techno Time']
# 49 Techno Time
# n:  3
# list:  49
# check : 1999.07
# input:  1999.07
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기', 'Na Na Na', '상상', 'Memory', 'Techno Time', 'Magic']
# 50 Magic
# n:  4
# list:  50
# check : 1999.07
# input:  1999.07
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기', 'Na Na Na', '상상', 'Memory', 'Techno Time', 'Magic', 'Vanessa']
# 51 Vanessa
# n:  5
# n:  1
# list:  1
# check : 2018.02.04
# n:  1
# list:  2
# check : 2018.01.25
# n:  1
# list:  3
# check : 2017.11.13
# n:  1
# list:  4
# check : 2017.10.28
# n:  1
# list:  5
# check : 2017.10.28
# n:  1
# list:  6
# check : 2017.10.28
# n:  1
# list:  7
# check : 2017.10.28
# n:  1
# list:  8
# check : 2017.10.28
# n:  1
# list:  9
# check : 2014.07.22
# n:  1
# list:  10
# check : 2014.06.09
# n:  1
# list:  11
# check : 2005.11.18
# n:  1
# list:  12
# check : 2005.11.18
# n:  1
# list:  13
# check : 2005.11.18
# n:  1
# list:  14
# check : 2005.11.18
# n:  1
# list:  15
# check : 2005.11.18
# n:  1
# list:  16
# check : 2005.11.18
# n:  1
# list:  17
# check : 2005.11.18
# n:  1
# list:  18
# check : 2005.11.18
# n:  1
# list:  19
# check : 2005.11.18
# n:  1
# list:  20
# check : 2005.11.18
# n:  1
# list:  21
# check : 2005.11.18
# n:  1
# list:  22
# check : 2005.11.18
# n:  1
# list:  23
# check : 2004.04.30
# n:  1
# list:  24
# check : 2004.04.30
# n:  1
# list:  25
# check : 2004.04.30
# n:  1
# list:  26
# check : 2004.04.30
# n:  1
# list:  27
# check : 2004.04.30
# n:  1
# list:  28
# check : 2004.04.30
# n:  1
# list:  29
# check : 2004.04.30
# n:  1
# list:  30
# check : 2004.04.30
# n:  1
# list:  31
# check : 2004.04.30
# n:  1
# list:  32
# check : 2004.04.30
# n:  1
# list:  33
# check : 2004.04.30
# n:  1
# list:  34
# check : 2004.04.30
# n:  1
# list:  35
# check : 2004.04.30
# n:  1
# list:  36
# check : 2004.04.30
# n:  1
# list:  37
# check : 2003.09.08
# n:  1
# list:  38
# check : 2003.09.08
# n:  1
# list:  39
# check : 2003.02.07
# n:  1
# list:  40
# check : 2003.02.07
# n:  1
# list:  41
# check : 2003.02.07
# n:  1
# list:  42
# check : 2003.02.07
# n:  1
# list:  43
# check : 2003.02.07
# n:  1
# list:  44
# check : 2003.02.07
# n:  1
# list:  45
# check : 2003.02.07
# n:  1
# list:  46
# check : 2003.02.07
# n:  1
# list:  47
# check : 2003.02.07
# n:  1
# list:  48
# check : 2003.02.07
# n:  1
# list:  49
# check : 2003.02.07
# n:  1
# list:  50
# check : 2003.02.07
# n:  1
# n:  1
# list:  1
# check : 2000.04.12
# n:  1
# list:  2
# check : 2000.04.12
# n:  1
# list:  3
# check : 2000.04.12
# n:  1
# list:  4
# check : 2000.04.12
# n:  1
# list:  5
# check : 2000.04.12
# n:  1
# list:  6
# check : 2000.04.12
# n:  1
# list:  7
# check : 2000.04.12
# n:  1
# list:  8
# check : 2000.04.12
# n:  1
# list:  9
# check : 2000.04.12
# n:  1
# list:  10
# check : 1999.01.12
# input:  1999.01.12
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기', 'Na Na Na', '상상', 'Memory', 'Techno Time', 'Magic', 'Vanessa', '그대야 미안해']
# 52 그대야 미안해
# n:  2
# list:  11
# check : 1998.11
# input:  1998.11
# title: ['떠나가지 마세요', '학교 (Main Title)', '떠나가지 마세요', '나의 슬픈 사랑이야기', '사랑연가', '댄스! 댄스! 댄스!', '하얀 사랑', '낮과 밤', '인연', '검은 위선', 'Love Song #2', 'Run', 'Play Boy', 'Goodbye', '우리가 시작할때...거기엔 랩이 있었다', 'Intro', '꽃', '승리', 'Pang Pang', '빠삐용 (그의 두통은 자유였다)', '마라! 봐라!', '아니벌써', 'Silver Line', 'True Love', '반쪽만의 사랑 (My Teacher)', '히든 카드', '세상에 던지는 한마디', 'Pang Pang (나보다 나은 너)', 'Intro', 'Be My Guest', '환상체험', '건망증', '이럴수가', 'Love Story', '통화중 (감기)', '삼인사각', '어쨌건...', '도사 (Jungle Trance)', '귀여운 악마', 'Bow Wow', 'Home Boy', 'Street Boy', '둘만의 사랑', '꿈속의 그녀', '노래 이야기', 'Na Na Na', '상상', 'Memory', 'Techno Time', 'Magic', 'Vanessa', '그대야 미안해', '와요와요']
# 53 와요와요
# n:  3
# n:  1
# list:  1
# check : 2015.08.17
# n:  1
# n:  1
# n:  1

# %% [markdown]
# ## Dataframe에 크롤링된 데이터 저장하기
# ### 이전 csv파일에서 남녀, 소속사를 크롤링한 데이터에 열 추가
# 1. '1996_1997_debut.csv 파일 읽기

# %%
idol_list = pd.read_csv('1996_1997_debut.csv',encoding = 'euc-kr')
idol_list.shape
# Out:
# (10, 7)

# %% [markdown]
# 2. 리스트 칼럼 확인

# %%
idol_list.columns
# Out:
# Index(['artist', 'artist_eng', 'member_num', 'leader_name', 'gender', 'agency',
#        'idol_id'],
#       dtype='object')

# %% [markdown]
# ## 성별 데이터
# 3. 최종 수집 결과에 성별이 영어로 표기되어 있으므로 바꿔주기

# %%
add_gender = []
add_gender = idol_list.gender
add_gender
# Out:
# 0    남
# 1    남
# 2    남
# 3    남
# 4    남
# 5    남
# 6    남
# 7    남
# 8    남
# 9    여
# Name: gender, dtype: object

# %%
# 성별 영어로 바꿔주기

for i in range(len(add_gender)):
    if(add_gender[i] == '남'):
        add_gender[i] = 'male'
    else:
        add_gender[i] = 'female'

add_gender
# Out:
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# 0      male
# 1      male
# 2      male
# 3      male
# 4      male
# 5      male
# 6      male
# 7      male
# 8      male
# 9    female
# Name: gender, dtype: object

# %% [markdown]
# ## 소속사 데이터

# %%
add_agency = []
add_agency = idol_list.agency
add_agency
# Out:
# 0         레오뮤직
# 1       뮤직 팩토리
# 2      DSP 미디어
# 3        비온디크루
# 4          매스컴
# 5       뮤직 팩토리
# 6       베토벤 뮤직
# 7            x
# 8    YG 엔터테인먼트
# 9         희레코드
# Name: agency, dtype: object

# %% [markdown]
# ### 크롤링 데이터에 성별, 소속사 추가하기

# %%
test_list = [title, release_date, song_genre, creator, lyrics]
column_names = ['년도','가수','제목','장르','작사가', '가사']
column_v = [release_date, artist, title, song_genre, creator, lyrics]

test_df = pd.DataFrame(column_v)

# %%
test_p = test_df.head(6).T
test_p.head()
# Out:
#             0     1                2   3                                   4  \
# 0  1999.08.01  언타이틀         떠나가지 마세요  댄스
# 1  1999.03.05  언타이틀  학교 (Main Title)   -
# 2  1999.02.01  언타이틀         떠나가지 마세요  댄스  유건형\n작사\n서정환\n작사\n유건형\n작곡\n유건형\n편곡
# 3  1999.02.01  언타이틀      나의 슬픈 사랑이야기  댄스           유건형\n작사\n유건형\n작곡\n유건형\n편곡
# 4  1999.02.01  언타이틀             사랑연가  댄스           유건형\n작사\n유건형\n작곡\n유건형\n편곡
#
#                                                    5
# 0
# 1  다시 바꿔 생각해 너무 억울한걸\n다른 위치라면은 누구나 같은데\n학교폭력에 숨진 ...
# 2  난 울고 있어요 그대도 아시나요\n미치도록 아픈 나의 가슴을\n그대 날 떠난 후엔 ...
# 3  이젠 늦었어요 이미 그녀는\n다른 곳에 있죠 사랑한다는\n그 말 한마디 못한 채\n...
# 4  누굴 좋아해야 하나요\n누굴 사랑해야 하나요\n누굴 향해 고백하나요\n난 정말 알 ...

# %%
c_artist = []
c_artist = test_p.가수

# %% [markdown]
# 1. 성별 추가하기

# %%
tmp_artist = []
tmp_artist = idol_list.artist

# %%
a_gender = []

for i in range(len(c_artist)) :
    if( c_artist[i] == tmp_artist[8] ):
        a_gender.append(add_gender[9])
    else :
        a_gender.append(add_gender[0])
#a_gender

# %% [markdown]
# 2. 소속사 추가하기

# %%
a_agency = []

for i in range(len(c_artist)) :
    if( c_artist[i] == tmp_artist[0] ):
        a_agency.append(add_agency[0])
    elif( c_artist[i] == tmp_artist[1] ):
        a_agency.append(add_agency[1])
    elif( c_artist[i] == tmp_artist[2] ):
        a_agency.append(add_agency[2])
    elif( c_artist[i] == tmp_artist[3] ):
        a_agency.append(add_agency[3])
    elif( c_artist[i] == tmp_artist[4] ):
        a_agency.append(add_agency[4])
    elif( c_artist[i] == tmp_artist[5] ):
        a_agency.append(add_agency[5])
    elif( c_artist[i] == tmp_artist[6] ):
        a_agency.append(add_agency[6])
    elif( c_artist[i] == tmp_artist[7] ):
        a_agency.append(add_agency[7])
    elif( c_artist[i] == tmp_artist[8] ):
        a_agency.append(add_agency[8])
    else :
        a_agency.append(add_agency[9])
#a_agency

# %% [markdown]
# ### 작사가 작곡가 나누기
# 1. 시험삼아 1개만 일단 해보기

# %%
creator[2]
# Out:
# '유건형\n작사\n서정환\n작사\n유건형\n작곡\n유건형\n편곡'

# %%
arr = []
tmp_arr = []
tmp = ""
lyricist = []
composer = []

l_idx = 0

arr = creator[2].split('작사')
print("arr : ", arr)
for i in range(len(arr)):
    if( '작곡' in arr[i]): 
        tmp_arr = arr[i].split('작곡')
        #print("tmp_arr:", tmp_arr)
        composer.append(tmp_arr[0].replace("\n",""))
        
    else:
        if( l_idx == 0): 
            lyricist.append(arr[i].replace("\n",""))   
            l_idx += 1
        else :
            lyricist[l_idx-1] += ','
            lyricist[l_idx-1] += arr[i].replace("\n","")
 
print("작곡가: " ,composer)
print("작사가: ", lyricist[0])
# Out:
# arr :  ['유건형\n', '\n서정환\n', '\n유건형\n작곡\n유건형\n편곡']
# 작곡가:  ['유건형']
# 작사가:  유건형,서정환

# %% [markdown]
# 2. 전체 적용

# %%
add_lyricist = []
add_composer = []
arr = []
tmp_arr = []
tmp = ""



#print(creator)
for j in range(len(creator)):
    if( creator[j] == ""):
        add_lyricist.append("")
        add_composer.append("")
        continue
    arr = creator[j].split('작사')
    #print(j,":",arr)
    l_idx = 0
    for i in range(len(arr)):
        if( '작곡' in arr[i]): 
            tmp_arr = arr[i].split('작곡')
            #print("tmp_arr:", tmp_arr)
            add_composer.append(tmp_arr[0].replace("\n",""))
        else:

            if( l_idx == 0) :
                add_lyricist.append(arr[i].replace("\n",""))   
                l_idx += 1
            else :
                l_idx = len(add_lyricist)
                print(len(add_lyricist))
                add_lyricist[l_idx-1] += ','
                add_lyricist[l_idx-1] += arr[i].replace("\n","")
             
#print("작사가: ",add_lyricist) 
#print("작곡가: " ,add_composer)
# Out:
# 3
# 7
# 10
# 11

# %% [markdown]
# ### 안타깝게도 최고순위는 직접...ㅎ..

# %%
rank = []

# %%
column_names = ['년도','가수','제목','남녀','장르','최고순위','작사가','작곡가','소속사' ,'가사']
column_v = [release_date, artist, title, a_gender, song_genre,rank,add_lyricist,add_composer,a_agency, lyrics]
test_df = pd.DataFrame(column_v)

# %%
test_p = test_df.head(10).T
test_p.head()
# Out:
#             0     1                2     3   4     5        6    7     8  \
# 0  1999.08.01  언타이틀         떠나가지 마세요  male  댄스  None                레오뮤직
# 1  1999.03.05  언타이틀  학교 (Main Title)  male   -  None                레오뮤직
# 27  어딜가도 이런 여잔 없을거야\n세상에 이럴 수가 했었지\n우연히 날아온 괜찮은 그녀...
# 28
# 29
# 30  마음이 두근 두근\n가슴이 조마 조마\n첫눈에 널 보고\n콩깍지가 씌어졌어\n바로 ...
# 31  그 여자 왜 나를 모른척 할까\n나 먼저 손들어 아는척 했는데\n못 본척 하는 그 ...
# 32  언젠가 우리들이 압구정동 나갔을때\n저 앞을 가는 내 이상형을 보고 말았지\n난 너...
# 33  해가 감기 들도록 눈이 내린날\n너는 우리 동네에 이사왔어\n나는 친구들과 눈 사람...
# 34  아까는 미안 baby\n정말로 미안 baby\n내맘은 아냐 baby\n내맘이 정말 ...
# 35  항상 셋이야 우린 친구야\n하지만 혼자야 너흰 단짝이니\n처음부터 너를 사랑한건 아...
# 36  나는 지금 홀로 앉아\n신나게 피아노치며\n눈이 오는 한밤 중에\n눈을 감고 노랠 ...
# 37  지리산 계룡산 오대산 남산\n산에라도 들어가서\n도를 닦아볼까\n수리수리 마수리\n...
# 38
# 39  TV보기 전자 오락하기\n미성년자는 못보는 영화보기\n어른 손잡고 어딜갈거야\n넌 ...
# 40  이른 아침 눈을 뜨며 걱정했어\n오늘은 또 누군가와\n어떤 얘기를 하며\n보내야 하...
# 41  WOO HE\nCHECK BABY CHECK IT OUT\nWOO HE\nCHECK...
# 42  어쩌면 너도 나만큼\n그리워 했었는지도 몰라\n이런 날\n지금쯤 네게 보낸\n어색한...
# 43  난 매일 저녁 집을 향해 걸을 때마다\n또 혹시 그녈 볼까하는 기댈 했어\n내 나이...
# 44  이젠 나의 노래 있어 좋아\n지금 내겐 노래 있어 좋아\n내 맘대로 노래해도 좋아\...
# 45  NA NA NA NA\nNA NA NA NA NA NA NA NA\n왜 그렇게 울고...
# 46  언제나 믿었어\n믿고 싶던 너였어\n근데 그게 아니었어\n너로 인해 짧은 하루가\n...
# 47  하나 둘씩 집으로\n돌아가려 하는 저녁 무렵\n어느새 다가와 있는 찬바람이\n한 계...
# 48  나의 방황 네게 얻은 당황\n또 네게 남은시련 내게 남아있는 미련\n비련해진 내 모...
# 49  물끄러미 나를 바라보는\n은근히 바란 너희들의 속셈\n알고 있어\n나는 내가 먼저 ...
# 50  I love you 떨리는\n목소리로 넌 내게 고백을 했어\nI love you t...
# 51
# 52
# 53                                               None
# 54                                               None
# 55                                               None

# %%
test_p.shape
# Out:
# (56, 10)

# %%
# 곡 전처리
test_p['제목'].isnull().sum()
# Out:
# 3

# %%
test_p.tail()
# Out:
#             년도    가수       제목    남녀    장르  최고순위   작사가   작곡가     소속사    가사
# 51     1999.07   엔알지  그대야 미안해  male    댄스  None              뮤직 팩토리
# 52     1999.07   엔알지     와요와요  male    댄스  None              뮤직 팩토리
# 53     1999.07  None     None  male  None  None  None  None    희레코드  None
# 54  1999.01.12  None     None  male  None  None  None  None    희레코드  None
# 55     1998.11  None     None  male  None  None  None  None    희레코드  None

# %%
test_p.to_csv('k_pop_3.tsv',index=False,header=None,sep='\t') #tsv파일로 저장
