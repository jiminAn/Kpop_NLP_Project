# %%
# !pip install html5lib beautifulsoup4
# Out:
# Requirement already satisfied: html5lib in c:\users\user\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\user\anaconda3\lib\site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4) (2.0.1)

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\user\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.25.9)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from time import sleep
import requests
import json
import re
import pandas as pd

# %%
from urllib import request
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException

# %%
from selenium.webdriver.common.keys import Keys

# %%
idol_list = pd.read_csv('1992to1999_idol_list.csv', encoding = 'utf-8')
idol_list.shape
# Out:
# (47, 6)

# %%
idol_list.columns
# Out:
# Index(['artist', 'artist_eng', 'member_num', 'leader_name', 'gender',
#        'agency'],
#       dtype='object')

# %%
artists = idol_list.artist
artists[1]
# Out:
# '더 블루'

# %%
path = r"C:\Users\user\Downloads\chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get("https://www.melon.com/search/total/index.htm?q=%EC%86%8C%EB%85%80%EC%8B%9C%EB%8C%80&section=&searchGnbYn=Y&kkoSpl=N&kkoDpType=&ipath=srch_form")

# %%
artist_id = []

# %%
# n=0
tmp = []
id = ""
for artist in artists:
    sleep(3)
    search = driver.find_element_by_xpath('//*[@id="top_search"]')
    search.send_keys(Keys.CONTROL + "a");
    search.clear()
    #WebDriverWait(driver, timeout)
    search.send_keys(artist)

    # 아티스트명 검색
    search.send_keys(Keys.RETURN)

    try:
        
        # 아티스트 클릭
        driver.find_element_by_xpath('//*[@id="conts"]/div[3]/div[1]/div[1]/div/a/strong').click()
        url = driver.current_url
        tmp = url.split('=')
        id = tmp[1]
        print(artist,id)
        artist_id.append(id)

    
    except NoSuchElementException:
        artist_id.append('')
# Out:
# 서태지와 아이들 100161
# 더 블루 180144
# 잼 101781
# 솔리드 100037
# 듀스 100977
# 노이즈 100025
# 룰라 106610
# 쿨 100004
# 제트 108871
# 터보 100059
# 알이에프 100015
# 스머프 247880
# 에이치오티 100008
# 언타이틀 100042
# 하모하모 100178
# 구피 100023
# 태사자 100096
# 엔알지 100010
# 오피피에이 100013
# 티앤비 101868
# 젝스키스 100052
# 쎄쎄쎄 1272877
# 베이비복스 216382
# 에스이에스 100016
# 원타임 100001
# 신화 100078
# 이글 파이브 100051
# 팬클럽 848990
# 써클 100036
# 쿠키 2858547
# 핑클 100065
# 플라이 투 더 스카이 100183
# 에이포 100763
# 클릭비 100070
# 와이투케이 100021
# god 100007
# 문차일드 100185
# 오투알 100011
# 씨유 549100
# 클레오 101397
# 티티마 100017
# 오투포 100121

# %%
len(artist_id)
# Out:
# 47

# %%
idol_id = artist_id.copy()

# %%
idol_id = pd.DataFrame(idol_id)
idol_id.head()
# Out:
#         0
# 0  100161
# 1  180144
# 2  101781
# 3
# 4  100037

# %%
idol_id.columns = ['idol_id']

# %%
idol_id.head()
# Out:
#   idol_id
# 0  100161
# 1  180144
# 2  101781
# 3
# 4  100037

# %%
idol_list.head()
# Out:
#      artist         artist_eng member_num leader_name gender     agency
# 0  서태지와 아이들  SeoTaiji And Boys          3         서태지      남      요요 기획
# 1      더 블루           The Blue          2         손지창      남  SM 엔터테인먼트
# 2         잼                Zam          5         조진수      혼    DSP 미디어
# 3     에스오에스              S.O.S          4         NaN      여    삼포니 레코드
# 4       솔리드              Solid          3         정재윤      남        비앤비

# %%
idol_list['idol_id'] = 0

# %%
len(idol_id)
# Out:
# 47

# %%
idol_list.update(idol_id)

# %%
idol_list
# Out:
#          artist         artist_eng member_num leader_name gender  \
# 0      서태지와 아이들  SeoTaiji And Boys          3         서태지      남
# 1          더 블루           The Blue          2         손지창      남
# 2             잼                Zam          5         조진수      혼
# 3         에스오에스              S.O.S          4         NaN      여
# 4           솔리드              Solid          3         정재윤      남
# 5            듀스               DEUX          2         이현도      남
# 6           노이즈              Noise          4         홍종구      남
# 7            잉크                ink          7         이상원      남
# 8            룰라             Roo'Ra          4         이상민      혼
# 9             쿨               Cool      3 (4)         김성수      혼
# 10           제트                  Z          3         NaN      남
# 11           터보              Turbo      3 (2)         김정남      남
# 12         알이에프               R.ef          3         박철우      남
# 13          스머프             Smurph          5         이희성      혼
# 14        에이치오티             H.O.T.          5         문희준      남
# 15         언타이틀            Untitle          2         유건형      남
# 16         하모하모          HAMO HAMO          2         이성진      남
# 17          아이돌               IDOL          2         최혁준      남
# 18           구피              Goofy          3         이승광      남
# 19          태사자            Taesaja          4         김형준      남
# 20          엔알지              N.R.G      3 (5)         이성진      남
# 21        오피피에이            O.P.P.A          8         김영훈      남
# 22          티앤비                TNB          5          손혁      남
# 23         젝스키스         Sechs Kies          6         은지원      남
# 24          쎄쎄쎄           Se Se Se          3         NaN      여
# 25        베이비복스         Baby V.O.X          5         김이지      여
# 26        에스이에스             S.E.S.          3          바다      여
# 27          원타임               1TYM          4          테디      남
# 28           신화            SHINHWA          6          에릭      남
# 29       이글 파이브         Eagle Five          5         윤성준      남
# 30    오피피에이 공공칠           OPPA 007          5         NaN      남
# 31          팬클럽           Fan Club          6         홍상진      남
# 32           써클             Circle          5         이지현      여
# 33           쿠키              Cooki          3          유나      여
# 34           핑클           Fin.K.L.          4         이효리      여
# 35  플라이 투 더 스카이     Fly To The Sky          2         NaN      남
# 36          에이포                 A4          4         이제희      남
# 37          클릭비            Click-B          7         김태형      남
# 38        와이투케이                Y2K          3         고재근      남
# 39          god                god          5         박준형      남
# 40         문차일드          Moonchild          4          이수      남
# 41          오투알                O2R          5         NaN      남
# 42           씨유              See U          3          지니      여
# 43           폭스              F.O.X          4         NaN      여
# 44          클레오               Cleo          3         김하나      여
# 45          티티마             T.T.Ma          5          소이      여
# 46          오투포               O-24          3         이가혜      여
#
#                      agency  idol_id
# 0                     요요 기획   100161
# 1                 SM 엔터테인먼트   180144
# 2                   DSP 미디어   101781
# 3                   삼포니 레코드
# 4                       비앤비   100037
# 5            예당 음향 (예당 컴퍼니)   100977
# 6                     라인 기획   100025
# 7                       NaN
# 8                  서울인 프로덕션   106610
# 9                      쿨컴퍼니   100004
# 10                      NaN   108871
# 11                 더 터보 컴퍼니   100059
# 12                 팀 엔터테인먼트   100015
# 13                      NaN   247880
# 14                SM 엔터테인먼트   100008
# 15           예당 음향 (예당 컴퍼니)   100042
# 16                   뮤직 팩토리   100178
# 17                  DSP 미디어
# 18                      NaN   100023
# 19                      매스컴   100096
# 20                   뮤직 팩토리   100010
# 21                   베토벤 뮤직   100013
# 22                      NaN   101868
# 23  YG 엔터테인먼트?(결성은?DSP 미디어)   100052
# 24                     희레코드  1272877
# 25                    DR 뮤직   216382
# 26                SM 엔터테인먼트   100016
# 27                YG 엔터테인먼트   100001
# 28   신화 컴퍼니?(결성은?SM 엔터테인먼트)   100078
# 29                      NaN   100051
# 30                   베토벤 뮤직
# 31                      NaN   848990
# 32                    조선 음향   100036
# 33                드림 엔터테인먼트  2858547
# 34                  DSP 미디어   100065
# 35   H2 미디어?(결성은?SM 엔터테인먼트)   100183
# 36                      NaN   100763
# 37                  DSP 미디어   100070
# 38                    조선 음향   100021
# 39               iHQ?(싸이더스)   100007
# 40                    GM 기획   100185
# 41                      NaN   100011
# 42                    동아 기획   549100
# 43                O.G SOUND
# 44                 호 엔터테인먼트   101397
# 45                   뮤직 팩토리   100017
# 46                    은성 기획   100121

# %%
idol_list.to_csv('idol_list_with_id.csv')
