# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(r'C:\Users\user\Downloads\chromedriver_win32/chromedriver.exe')

# %%
singer=  ['원타임','신화','이글 파이브','써클','핑클','코요태','에이포','클릭비','와이투케이','god','클레오','티티마']
singer_id =[]

# %%
for i in singer:
    driver.get("https://www.melon.com/index.htm")   
    search = driver.find_element_by_xpath('//*[@id="top_search"]') #검색창 xpath
    search.clear() #검색창 clear
    search.send_keys(i+'\n')  #검색창에 가수 입력후 엔터
    
    driver.find_element_by_xpath('//*[@id="conts"]/div[3]/div/div[1]/div/a/strong').click() #검색한 아티스트 클릭
    url = driver.current_url
    id = url.replace('https://www.melon.com/artist/timeline.htm?artistId=', '') #url에 있는 가수 고유번호 저장
    
    singer_id.append(id)

# %%
print(singer_id)
# Out:
# ['100001', '100078', '100051', '100036', '100065', '100022', '100763', '100070', '100021', '100007', '101397', '100017']

# %%
title_ary=[]
date_ary=[]
genre_ary=[]
lyrics_ary=[]
lyricist_ary=[]
composer_ary=[]
singer_ary=[]

# %%
def search(id,n):   # 가수id를 받아 (제목,가수,가사, 발매일,장르,작사,작곡)  n개 만큼탐색  
    #id에 맞는 가수의 곡 페이지(인기순)으로 이동
    driver.get('https://www.melon.com/artist/song.htm?artistId='+str(id)+'#params%5BlistType%5D=A&params%5BorderBy%5D=POPULAR_SONG_LIST&params%5BartistId%5D='+str(id)+'&po=pageObj&startIndex=1')
    driver.implicitly_wait(1)

    for i in range(1,n+1):

        driver.execute_script('window.scrollTo(0,200)')
        
        # i번째 곡정보 클릭
        driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr['+ str(i)+']/td[3]/div/div/a[1]').click()
        
        # 발매일 먼저 검사
        str_tmp=driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[2]').text
        arr = str_tmp.split('.')
        
        # 발매일이 94년~99년까지인 곡만 정보 수집
        if( int(arr[0]) < 2000 and int(arr[0]) > 1997):
            #print("input: ", str_tmp)
            date_ary.append(str_tmp)
            
            title=driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[1]')
            title_ary.append(title.text)
            print(title)
            singer=driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a/span[1]')
            singer_ary.append(singer.text)
            
            genre=driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]')
            genre_ary.append(genre.text)
            
            try:
                lyricist=driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul/li[1]/div[2]/div[1]/a')
                lyricist_ary.append(lyricist.text)
            except:
                lyricist_ary.append('NULL')
        
            try:
                composer=driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul/li[2]/div[2]/div[1]/a')
                composer_ary.append(composer.text)
            except:
                composer_ary.append('NULL')
        
            try:
                lyrics=driver.find_element_by_xpath('//*[@id="d_video_summary"]')
                lyrics_ary.append(lyrics.text.replace('\n',' '))
            except:
                lyrics_ary.append('NULL')
            
            driver.back() #뒤로가기 ->다시 곡 목록으로 이동
            
        else:
            driver.back()

# %%
for i in singer_id:
    search(i,20)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="138c189e-70b1-49af-9244-61508a3c3042")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="54f9fd00-460b-47a2-a843-0df23ffaa678")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="a741eacd-69bd-4971-b0da-d828049c4b52")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="344e5e1e-06b7-4486-94e5-9f12eb5d4608")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="67f119f2-0b88-44b4-8a98-9fa4335f80ee")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="464d25e5-6973-40d7-968e-2b76edb8cb0f")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="109f1a6f-8751-426d-9f28-96f869fc3b0a")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="26459a5d-425f-48f2-a2e6-803e9c61ab5d")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="e8c691a0-b37b-42ba-9c2b-e7daffb2dbf8")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="5757114e-4bb0-46cb-9520-3378616bfa37")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="f125632b-5694-4daf-bc8e-110c80cadd5f")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="bdbf92e1-8610-453f-a854-c9ecee88e45f")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="cfc98b43-f733-43ca-8d06-295df1281103")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="a686e3d3-02ea-4003-b2fe-c85ecc2b6299")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="adc9df20-28fc-41d7-a151-718d92eac1da")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="f2148f0a-c7d3-430a-ac7f-9443bc1b56fa")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="68d440de-9bec-43cc-a923-b3fe22a61794")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="b6e67edc-e638-4068-81c2-545a19c05cd5")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="f0f3f327-af2e-455a-83c8-63513fa10c0c")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="d4f3e602-8f0a-4637-85f9-44b9b4ab49bf")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="8702abec-e97f-4ec9-87b4-6cc28cbebaf5")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="e1c7376d-c3f7-48d5-ad3b-b144eabd9237")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="49f1b74c-2c7a-46db-b58b-5ff2c11e5a2d")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="65d23093-2647-417a-ac54-3f80ded0ce44")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="1a862b0e-08ff-4a25-97d4-4e1d82d752da")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="1dfed12a-4f76-4ad3-b49b-253ffbbce630")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="b165a587-cc22-4b6c-b44a-32871fbc7b2d")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="0d944add-9fe4-44d6-8d74-dcf9377645cb")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="630f8a8e-1233-4281-8cb8-3a7b405012e8")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="9073fbfd-b982-4aad-a1fb-f2e435c7f718")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="5b6d0ae2-7a1b-40ae-a71e-960adb5ed5c7")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="a70100c4-adc7-4653-ab87-1a0f419f067e")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="fb1ca94e-cf12-42dd-901d-05c92be59de7")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="825648ba-326f-473b-8e51-58bf2c0e3897")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="32d3271f-8503-4337-b00e-3a06a82a3b13")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="1b6c8a00-8af4-4490-a49c-eae456946061")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="04931e64-6739-4ac0-b65f-6de80712b03c")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="ebf92433-d60f-4661-ba1b-2928b7848f2f")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="d0bb0308-c4e0-453c-8363-24b2e4693621")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="e09fe54f-0857-4c9c-9ef9-b33c8dd9ecc5")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="08eb770c-0de0-4045-aec6-070112e0cfff")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="f25be786-657d-4f5a-8afe-890053c883a6")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="a5484886-7e1d-466f-8382-e5801b52daee")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="3e67f63d-a6b4-42dc-84e7-a96c5dcdf742")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="6f7be280-7561-4ab5-aa64-31ca3eff58d1")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="223f7edf-944f-43bd-a721-ba6cf85f3c8f")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="dd74435d-b731-499d-b857-2ad1daf6892d")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="53e73b26-ca91-4525-96b1-1ab0f29bd49c")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="533ec43b-ca40-4038-b943-1ec3fc9a9090")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="34fdd47d-6be4-49a5-9010-44b0e7647480")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="cc4e6db8-b958-431c-9ac5-b0fb43e268e0")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="afa6bf3c-a1de-4818-b932-81981c360a2b")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="9d8497b7-83f7-4cbc-a48f-be17b28015ef")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="d2d2eb2e-38e8-4a15-99a8-5719bdd6a847")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="74455d3f-ebca-4105-9389-c9ee608a6c8a")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="f646a143-4909-4987-89da-3be594623249")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="7c50af46-26da-4f96-b424-04deecdb78a4")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="18cd3693-aa46-4610-8660-766b0ff739eb")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="95df2aa1-8c29-453c-8ed1-50a051c5bbaa")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="b50ea491-69b7-4235-ba1c-27078941052b")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="b9c5bf32-7c40-42c2-b622-c6bc304e1c2b")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="2956ccf1-9018-4eb5-977b-58bd672e1bef")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="5ffae6d8-b203-4715-97da-3a2fa30889ff")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="8c617bc1-ab4c-4b8b-8884-a4617ef1f747")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="a339d2b4-1b4d-4ddf-8f0c-10e72340fa8f")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="509705c1-69ba-4edf-8478-324d05ee85bb")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="536d6a12-5b21-48d6-a0df-28c77907d9f1")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="44618e5a-21b1-4300-919a-1d8336dd99ad")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="a657bf3e-c62f-431a-977e-609b04e8e82f")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="9a9952cf-3fce-43d6-b2db-1c917629a54f")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="dba2c310-d746-412d-a5e4-3946045f3989")>
# <selenium.webdriver.remote.webelement.WebElement (session="d6f5916436fe198436f420dcd31fd442", element="d8c4d014-5cc3-408c-816a-925a6419b89f")>

# %%
import pandas as pd
df=pd.DataFrame({"년도":date_ary,"가수":singer_ary,"제목":title_ary,"장르":genre_ary,
                 "작사가":composer_ary,"작곡가":lyricist_ary,"가사":lyrics_ary})

# %%
df
# Out:
#             년도   가수                              제목    장르     작사가  \
# 0      1998.11  원타임                            1tym  랩/힙합      페리
# 1      1998.11  원타임                 Falling In Love  랩/힙합      페리
# 2      1998.11  원타임                       Good Love  랩/힙합      페리
# 3      1998.11  원타임                       뭘 위한 세상인가  랩/힙합  Q, 원타임
# 4      1999.04   신화  T.O.P. (Twinkling Of Paradise)    댄스    NULL
# ..         ...  ...                             ...   ...     ...
# 67  1999.05.01  티티마                      Come To Me    댄스     이윤상
# 68  1999.05.01  티티마                     A+ (A Plus)    댄스     최규성
# 69  1999.05.01  티티마                          Heaven    댄스     신명호
# 70  1999.05.01  티티마                         It`s Me    댄스     한창훈
# 71  1999.05.01  티티마                          Loving    댄스     최규성
#
#                   작곡가                                                 가사
# 0                 송백경  알겠어 와 와 우리도 지금까지 how how 너무도 긴 시간을 foul foul 참...
# 1                  페리  In love I think I'm fallin in love I think I'm...
# 2                  페리  yeah ha ha straight from the YG baby ah 1TYM 1...
# 3                 송백경  모두 망쳤어 모두 뺏겼어 다 모두 잠들어야만 했었어 과학이란 눈부심에 멀어진 너의 ...
# 4                NULL  What you gonna do what I gotta dokeep me up an...
# ..                ...                                                ...
# 67                이현규  누가 너를 내곁에서 뺏어 갔는지 난 너없이는 한순간도 살아갈 자신조차 없는데 내 가...
# 68                유유진  A몰래 B만난 건 단 두 번뿐야 그런데 왜 내 맘 흔들릴까 나만 생각하고 너무 착한...
# 69  박선주 (Pak Sun Zoo)  이제는 그런 대로 괜찮아 어느새 일년이 지났어 널 보낸지 oh my love 유난히...
# 70                김영아                                               NULL
# 71                최규성  지금 내겐 너밖에 없는데 너를 언제까지 지킬 자신이 없는 내 모습이 너무 초라해 요...
#
# [72 rows x 7 columns]

# %%
idol_list = pd.read_csv('98to99_idol_list.csv', encoding ='euc-kr')
idol_list.shape
# Out:
# (20, 6)

# %%
idol_list.columns
# Out:
# Index(['artist', 'artist_eng', 'member_num', 'leader_name', 'gender',
#        'agency'],
#       dtype='object')

# %%
idol_list.columnsadd_gender = []
add_gender = idol_list.gender
add_gender
# Out:
# <ipython-input-12-5550680fb108>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   idol_list.columnsadd_gender = []
# 0     남
# 1     남
# 2     남
# 3     남
# 4     남
# 5     여
# 6     여
# 7     여
# 8     남
# 9     남
# 10    남
# 11    남
# 12    남
# 13    남
# 14    남
# 15    여
# 16    여
# 17    여
# 18    여
# 19    여
# Name: gender, dtype: object

# %%
# 성별 영어로 바꿔주기

for i in range(len(add_gender)):
    if(add_gender[i] == '남'):
        add_gender[i] = 'male'
    else:
        add_gender[i] = 'mixed'

add_gender
# Out:
# <ipython-input-13-5b0b149cc5eb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_gender[i] = 'male'
# <ipython-input-13-5b0b149cc5eb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_gender[i] = 'mixed'
# 0      male
# 1      male
# 2      male
# 3      male
# 4      male
# 5     mixed
# 6     mixed
# 7     mixed
# 8      male
# 9      male
# 10     male
# 11     male
# 12     male
# 13     male
# 14     male
# 15    mixed
# 16    mixed
# 17    mixed
# 18    mixed
# 19    mixed
# Name: gender, dtype: object

# %%
add_agency = []
add_agency = idol_list.agency
add_agency
# Out:
# 0                  YG 엔터테인먼트
# 1     신화 컴퍼니?(결성은?SM 엔터테인먼트)
# 2                        NaN
# 3                     베토벤 뮤직
# 4                        NaN
# 5                      조선 음향
# 6                  드림 엔터테인먼트
# 7                    DSP 미디어
# 8     H2 미디어?(결성은?SM 엔터테인먼트)
# 9                        NaN
# 10                   DSP 미디어
# 11                     조선 음향
# 12                iHQ?(싸이더스)
# 13                     GM 기획
# 14                       NaN
# 15                     동아 기획
# 16                 O.G SOUND
# 17                  호 엔터테인먼트
# 18                    뮤직 팩토리
# 19                     은성 기획
# Name: agency, dtype: object

# %%
test_list = [title_ary, date_ary, genre_ary, lyricist_ary, lyrics_ary]
column_names = ['년도','가수','제목','장르','작사가', '가사']
column_v = [date_ary, singer_ary, title_ary, genre_ary, lyricist_ary, lyrics_ary]

test_df = pd.DataFrame(column_v)

# %%
test_p = test_df.head(6).T
test_p.head()
# Out:
#          0    1                               2     3     4  \
# 0  1998.11  원타임                            1tym  랩/힙합   송백경
# 1  1998.11  원타임                 Falling In Love  랩/힙합    페리
# 2  1998.11  원타임                       Good Love  랩/힙합    페리
# 3  1998.11  원타임                       뭘 위한 세상인가  랩/힙합   송백경
# 4  1999.04   신화  T.O.P. (Twinkling Of Paradise)    댄스  NULL
#
#                                                    5
# 0  알겠어 와 와 우리도 지금까지 how how 너무도 긴 시간을 foul foul 참...
# 1  In love I think I'm fallin in love I think I'm...
# 2  yeah ha ha straight from the YG baby ah 1TYM 1...
# 3  모두 망쳤어 모두 뺏겼어 다 모두 잠들어야만 했었어 과학이란 눈부심에 멀어진 너의 ...
# 4  What you gonna do what I gotta dokeep me up an...

# %%
c_artist = []
c_artist = test_p[1]

# %%
c_artist
# Out:
# 0     원타임
# 1     원타임
# 2     원타임
# 3     원타임
# 4      신화
#      ...
# 67    티티마
# 68    티티마
# 69    티티마
# 70    티티마
# 71    티티마
# Name: 1, Length: 72, dtype: object

# %%
a_gender = []

for i in range(len(c_artist)) :
    if( c_artist[i] == "룰라"):
        a_gender.append(add_gender[0])
    elif( c_artist[i] == "쿨 (COOL)" ):
        a_gender.append(add_gender[1])
    elif( c_artist[i] == "터보"):
        a_gender.append(add_gender[2])
    else :
        a_gender.append(add_gender[3])
#a_gender

# %%
a_gender
# Out:
# ['male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male']

# %%
a_agency = []

for i in range(len(c_artist)) :
    if( c_artist[i] == "룰라"):
        a_agency.append(add_agency[0])
    elif( c_artist[i] =="쿨 (COOL)"):
        a_agency.append(add_agency[1])
    elif( c_artist[i] == "터보"):
        a_agency.append(add_agency[2])
    else:
        a_agency.append(add_agency[3])

#a_agency

# %%
a_agency
# Out:
# ['베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직',
#  '베토벤 뮤직']

# %%
rank = []

# %%
column_names = ['년도','가수','제목','남녀','장르','최고순위','작사가','작곡가','소속사' ,'가사']
column_v = [date_ary, singer_ary, title_ary, a_gender, genre_ary,rank,lyricist_ary,composer_ary,a_agency, lyrics_ary]
test_df = pd.DataFrame(column_v)

# %%
test_p = test_df.head(10).T
test_p.head()
# Out:
#          0    1                               2     3     4     5     6  \
# 0  1998.11  원타임                            1tym  male  랩/힙합  None   송백경
# 1  1998.11  원타임                 Falling In Love  male  랩/힙합  None    페리
# 2  1998.11  원타임                       Good Love  male  랩/힙합  None    페리
# 3  1998.11  원타임                       뭘 위한 세상인가  male  랩/힙합  None   송백경
# 4  1999.04   신화  T.O.P. (Twinkling Of Paradise)  male    댄스  None  NULL
#
#         7       8                                                  9
# 0      페리  베토벤 뮤직  알겠어 와 와 우리도 지금까지 how how 너무도 긴 시간을 foul foul 참...
# 1      페리  베토벤 뮤직  In love I think I'm fallin in love I think I'm...
# 2      페리  베토벤 뮤직  yeah ha ha straight from the YG baby ah 1TYM 1...
# 3  Q, 원타임  베토벤 뮤직  모두 망쳤어 모두 뺏겼어 다 모두 잠들어야만 했었어 과학이란 눈부심에 멀어진 너의 ...
# 4    NULL  베토벤 뮤직  What you gonna do what I gotta dokeep me up an...

# %%
test_p.columns = column_names
test_p.tail(350)
# Out:
#             년도   가수                              제목    남녀    장르  최고순위  \
# 0      1998.11  원타임                            1tym  male  랩/힙합  None
# 1      1998.11  원타임                 Falling In Love  male  랩/힙합  None
# 2      1998.11  원타임                       Good Love  male  랩/힙합  None
# 3      1998.11  원타임                       뭘 위한 세상인가  male  랩/힙합  None
# 4      1999.04   신화  T.O.P. (Twinkling Of Paradise)  male    댄스  None
# ..         ...  ...                             ...   ...   ...   ...
# 67  1999.05.01  티티마                      Come To Me  male    댄스  None
# 68  1999.05.01  티티마                     A+ (A Plus)  male    댄스  None
# 69  1999.05.01  티티마                          Heaven  male    댄스  None
# 70  1999.05.01  티티마                         It`s Me  male    댄스  None
# 71  1999.05.01  티티마                          Loving  male    댄스  None
#
#                   작사가     작곡가     소속사  \
# 0                 송백경      페리  베토벤 뮤직
# 1                  페리      페리  베토벤 뮤직
# 2                  페리      페리  베토벤 뮤직
# 3                 송백경  Q, 원타임  베토벤 뮤직
# 4                NULL    NULL  베토벤 뮤직
# ..                ...     ...     ...
# 67                이현규     이윤상  베토벤 뮤직
# 68                유유진     최규성  베토벤 뮤직
# 69  박선주 (Pak Sun Zoo)     신명호  베토벤 뮤직
# 70                김영아     한창훈  베토벤 뮤직
# 71                최규성     최규성  베토벤 뮤직
#
#                                                    가사
# 0   알겠어 와 와 우리도 지금까지 how how 너무도 긴 시간을 foul foul 참...
# 1   In love I think I'm fallin in love I think I'm...
# 2   yeah ha ha straight from the YG baby ah 1TYM 1...
# 3   모두 망쳤어 모두 뺏겼어 다 모두 잠들어야만 했었어 과학이란 눈부심에 멀어진 너의 ...
# 4   What you gonna do what I gotta dokeep me up an...
# ..                                                ...
# 67  누가 너를 내곁에서 뺏어 갔는지 난 너없이는 한순간도 살아갈 자신조차 없는데 내 가...
# 68  A몰래 B만난 건 단 두 번뿐야 그런데 왜 내 맘 흔들릴까 나만 생각하고 너무 착한...
# 69  이제는 그런 대로 괜찮아 어느새 일년이 지났어 널 보낸지 oh my love 유난히...
# 70                                               NULL
# 71  지금 내겐 너밖에 없는데 너를 언제까지 지킬 자신이 없는 내 모습이 너무 초라해 요...
#
# [72 rows x 10 columns]

# %%
test_p.shape
# Out:
# (72, 10)

# %%
# 곡 전처리
test_p['제목'].isnull().sum()
# Out:
# 0

# %%
test_p.tail()
# Out:
#             년도   가수           제목    남녀  장르  최고순위                작사가  작곡가  \
# 67  1999.05.01  티티마   Come To Me  male  댄스  None                이현규  이윤상
# 68  1999.05.01  티티마  A+ (A Plus)  male  댄스  None                유유진  최규성
# 69  1999.05.01  티티마       Heaven  male  댄스  None  박선주 (Pak Sun Zoo)  신명호
# 70  1999.05.01  티티마      It`s Me  male  댄스  None                김영아  한창훈
# 71  1999.05.01  티티마       Loving  male  댄스  None                최규성  최규성
#
#        소속사                                                 가사
# 67  베토벤 뮤직  누가 너를 내곁에서 뺏어 갔는지 난 너없이는 한순간도 살아갈 자신조차 없는데 내 가...
# 68  베토벤 뮤직  A몰래 B만난 건 단 두 번뿐야 그런데 왜 내 맘 흔들릴까 나만 생각하고 너무 착한...
# 69  베토벤 뮤직  이제는 그런 대로 괜찮아 어느새 일년이 지났어 널 보낸지 oh my love 유난히...
# 70  베토벤 뮤직                                               NULL
# 71  베토벤 뮤직  지금 내겐 너밖에 없는데 너를 언제까지 지킬 자신이 없는 내 모습이 너무 초라해 요...

# %%
test_p.to_csv('kpop_debut_9495.tsv',index=False,header=None,sep='\t')
